# %% [markdown]
# <a href="https://colab.research.google.com/github/riteshgupta614/Capstone-project-Telecom-Churn/blob/main/Telecom_Churn_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %% [markdown]
# Work Breakdown
#
# 1.Load data.
#
# 2.View data.
#
# 3.Data Cleaning.
#
# 4.Data Analysis.
#
# 5.results / conclusion.
#
# 6.Thankyou.

# %% [markdown]
# #1.Load Data Set

# %%
#Importing Automated exploratory data analysis using Pandas Profiling


#! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
#Importing Necessary Libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas_profiling
import plotly.offline as po
import plotly.graph_objs as go
# %matplotlib inline
from pandas_profiling import ProfileReport

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define the path where data is kept
file_path = '/content/drive/MyDrive/almabetter/CAPSTONE PROJECT/Telecom Churn.csv'

# %%
data=pd.read_csv(file_path)

# %% [markdown]
# #2.View Data
#
# 2.1. data.head()
#
# 2.2. data.shape()
#
# 2.3. data.info()
#
# 2.4. data.nunique()
#
# 2.5. data.duplicated().sum()
#
# 2.6. data.isnull.sum()
#
# 2.7. data.describe()

# %% [markdown]
# Variable Breakdown
#
# **State:**51 Unique States
#
# **Account length:**The number of days that this account has been active.
#
#
# **Area code:**415 relates to San Francisco,408 is of San Jose and 510 is of City of Okland.
#
#
# **International plan:**Yes Indicate International Plan is Present and No Indicates no subscription for Internatinal Plan.
#
#
# **Voice mail plan:**Yes Indicates Voice Mail Plan is Present and No Indicates no subscription for Voice Mail Plan.
#
#
# **Number vmail messages** :It indicates number of voice main Messages recieved my the customer.
#
# **Total day minutes:** Total Number of Minutes Spent By Customers in Morning.
#
#
# **Total day calls:**Total Number of Calls made by Customer in Morning.
#
#
# **Total day charge:**Total Charge to the Customers in Morning.
#
#
# **Total eve minutes:**Total Number of Minutes Spent By Customers in Evening
#
#
# **Total eve calls:**Total Number of Calls made by Customer in Evening.
#
#
# **Total eve charge:**Total Charge to the Customers in Morning.
#
#
# **Total night minutes:**Total Number of Minutes Spent By Customers in the Night.
#
#
# **Total night calls:**Total Number of Calls made by Customer in Night.
#
#
# **Total night charge:**Total Charge to the Customers in Night.
#
#
# **Total intl minutes:**Total Number of Minutes Spent By Customers on international calls.
#
#
# **Total intl calls:**Total Number of Calls made by Customer on international calls.
#
# **Total intl charge:**Total Charge to the Customers on international calls.
#
# **Customer service calls**:number of calls mae by the customers to the customer service.
#
#
# **Churn:** True = churned customer, False = retained customer

# %%
#Perform Exploratory Data Analysis in just one line of code


#pandas_profiling.ProfileReport(data)

# %%
#Pandas head() method is used to return top n (5 by default) rows of a data frame or series

data.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
#Return a tuple representing the dimensionality of the DataFrame.

data.shape
# Out:
# (3333, 20)

# %%
#.info = to print the full summary

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
#nunique() = function return number of unique elements in the object.

data.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
# Return boolean Series denoting duplicate rows.
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# # 3.Data Cleaning

# %% [markdown]
# 3.1. Drop unnecessary Column. - No Droping of column is requird.
#
# 3.2. Null values Treatment. - none Null Values Found
#
# 3.3. Outliners Treatment. - Ignoring this Step For Now

# %% [markdown]
# #4.Data analysis
#
# 4.1. Correlation Heat Map –
#
# 4.2. Univariate Analysis –
#
# 4.3  Bivariate data –
#
# 4.4. Multivariate data –

# %% [markdown]
# 4.1.  Correlation Heat Map –

# %%
# 4.1.  correlation between dataset - A correlation heatmap is a heatmap that shows a 2D correlation matrix between two discrete dimensions

corrmat = data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# 4.2.  Univariate data Analys

# %%
for i, predictor in enumerate(data.drop(columns=['Total day minutes',"Total eve minutes",'Total intl minutes','Total day charge','Total eve charge','Total night charge'])):
    plt.figure(i)
    sns.countplot(data=data, x=predictor, hue='Churn')

# %%
# Visualising Total Customer Churn
plot_by_churn_labels = data["Churn"].value_counts().keys().tolist()
plot_by_churn_values = data["Churn"].value_counts().values.tolist()

plot_data= [
    go.Pie(labels = plot_by_churn_labels,
           values = plot_by_churn_values,
           marker = dict(colors =  [ 'Teal' ,'Grey'],
                         line = dict(color = "white",
                                     width =  1.5)),
           rotation = 90,
           hoverinfo = "label+value+text",
           hole = .6)
]
plot_layout = go.Layout(dict(title = "Customer Churn",
                   plot_bgcolor  = "rgb(243,243,243)",
                   paper_bgcolor = "rgb(243,243,243)",))


fig = go.Figure(data=plot_data, layout=plot_layout)
po.iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
'''Separating churn and non churn customers
churn     = data[data["Churn"] == bool(True)]
not_churn = data[data["Churn"] == bool(False)]'''
# Out:
# 'Separating churn and non churn customers\nchurn     = data[data["Churn"] == bool(True)]\nnot_churn = data[data["Churn"] == bool(False)]'

# %%
#Replacing Yes/No values with 1 and 0
data['International plan'] = data['International plan'].replace({"Yes":1,"No":0}).astype(int)
data['Voice mail plan'] = data['Voice mail plan'].replace({"Yes":1,"No":0}).astype(int)

# %% [markdown]
#  # 4.3. Bivariate data Analysis

# %% [markdown]
# # 4.3.1. Checking Voice-Mail Feature affecting Churn Rate

# %%
#Voice-Mail Feautre Messages
print('Unique vmail messages',data['Number vmail messages'].unique())
data['Number vmail messages'].describe()
# Out:
# Unique vmail messages [25 26  0 24 37 27 33 39 30 41 28 34 46 29 35 21 32 42 36 22 23 43 31 38
#  40 48 18 17 45 16 20 14 19 51 15 11 12 47  8 44 49  4 10 13 50  9]
# count    3333.000000
# mean        8.099010
# std        13.688365
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max        51.000000
# Name: Number vmail messages, dtype: float64

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Number vmail messages',width=0.2, data = data)

# %% [markdown]
# We can Notice for Voice-Mail Feature when there are more than 15 voice-mail messages then certainly there is a churn indicating improving the voice-mail feature or setting a limit and check whether a customer is retianed.
#
# According to my hypothesis :¶
# *1.Voice-Mail Service Upgradation 2.Setting up a limit on Voice-Mail service strictly no more than 25 voice mails. 3.Quality Drop in Voice-Mail after 25 voice mails.**

# %% [markdown]
#  # 4.3.2  Checking  day time Affecting chern rate.

# %% [markdown]
#  Checking Total Day Minute for chern Rate.
#
# ---

# %%
print('Maximum number of minutes:',data['Total day minutes'].max(),'i.e. Max number of Hours  spent:',round(data['Total day minutes'].max()/60))
print('Minimum number of minutes:',data['Total day minutes'].min())
print('Average number of minutes:',data['Total day minutes'].mean())
# Out:
# Maximum number of minutes: 350.8 i.e. Max number of Hours  spent: 6
# Minimum number of minutes: 0.0
# Average number of minutes: 179.77509750975116

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total day minutes',width=0.2, data = data)

# %% [markdown]
# We can infer from above box-plot that with users spending more 225 minutes or more i.e. approx 4hrs tend to switch to other operator.¶
# According to my hypothesis, following would be the factors that should be implemented:
#
# 1.Network Disturbance during a Call.
#
# 2.Cracking sound or noise during a call.
#
# 3.Need to Upgrade or make smarter use of technologies like VoLTE to improve Voice Quality.
#
# 4.Network Upgradation

# %% [markdown]
#  Checking Total day calls for chern Rate.
#
# ---

# %%
print('Maximum number of calls:',data['Total day calls'].max())
print('Minimum number of calls:',data['Total day calls'].min())
print('Average number of calls:',data['Total day calls'].mean())
# Out:
# Maximum number of calls: 165
# Minimum number of calls: 0
# Average number of calls: 100.43564356435644

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total day calls',width=0.2, data = data)

# %% [markdown]
# We can infere here that on an average a 100 calls are made which is a good indication for the company.But we can also note that for the churn customer the median is slightly higher than 100 which indicates there are call drops which may lead to more calls in a morning

# %% [markdown]
# 3.3.   Checking Total day Charge for chern rate.
#
# ---

# %%
print('Maximum number of charge:',data['Total day charge'].max())
print('Minimum number of charge:',data['Total day charge'].min())
print('Average number of charge:',data['Total day charge'].mean())
# Out:
# Maximum number of charge: 59.64
# Minimum number of charge: 0.0
# Average number of charge: 30.562307230723093

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total day charge',width=0.2, data = data)

# %% [markdown]
# Well,Here we can clearly indicate a strategy a good strategy to be implemented. As from above infered box-plots we can conclude one thing i.e Customers having more minutes spent on the network tend to leave the it's subscription and from the above box-plot it clearly indicates that there is defect in the pricing startegy of the company.

# %% [markdown]
# According to my Hypothsis:
#
# 1.Startegy of pricing needs to be re-evaluated.
#
# 2.The Clients who have high call minutes and calls need a discount in the end.

# %% [markdown]
# # 4.3.3  Checking Evening time Affecting the Churn Rate.

# %% [markdown]
#  Checking Total evening minutes for churn Rate.
#
# ---

# %%
print('Maximum number of minutes:',data['Total eve minutes'].max(),'i.e. Max number of Hours  spent:',round(data['Total eve minutes'].max()/60))
print('Maximum number of minutes:',data['Total eve minutes'].min())
print('Average number of minutes:',data['Total eve minutes'].mean())
# Out:
# Maximum number of minutes: 363.7 i.e. Max number of Hours  spent: 6
# Maximum number of minutes: 0.0
# Average number of minutes: 200.98034803480346

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total eve minutes',width=0.2, data = data)

# %% [markdown]
#  Checking Total Evening calls affecting Churn rate.
#
# ---

# %%
print('Maximum number of calls:',data['Total eve calls'].max())
print('Minimum number of calls:',data['Total eve calls'].min())
print('Average number of calls:',data['Total eve calls'].mean())
# Out:
# Maximum number of calls: 170
# Minimum number of calls: 0
# Average number of calls: 100.11431143114311

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total eve calls',width=0.2, data = data)

# %% [markdown]
#   Checking Total Evening charge for Churn rate.
#
# ---

# %%
print('Maximum number of charge:',data['Total eve charge'].max())
print('Minimum number of charge:',data['Total eve charge'].min())
print('Average number of charge:',data['Total eve charge'].mean())
# Out:
# Maximum number of charge: 30.91
# Minimum number of charge: 0.0
# Average number of charge: 17.083540354035392

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total eve charge',width=0.2, data = data)

# %% [markdown]
# # 4.3.4  Checking night Time Affecting Churn Rate.

# %% [markdown]
#   Checking Total Night Minutes affecting churn rate.
#
# ---

# %%
print('Maximum number of minutes:',data['Total night minutes'].max(),'i.e. Max number of Hours  spent:',round(data['Total night minutes'].max()/60))
print('Minimum number of minutes:',data['Total night minutes'].min())
print('Average number of minutes:',data['Total night minutes'].mean())
# Out:
# Maximum number of minutes: 395.0 i.e. Max number of Hours  spent: 7
# Minimum number of minutes: 23.2
# Average number of minutes: 200.87203720372048

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total night minutes',width=0.2, data = data)

# %% [markdown]
# In Night, The Loyal Customers are spend more time is what the box-plot indicates!¶

# %% [markdown]
# 1.  Checking Total night calls affceting churn rate.
#
# ---

# %%
print('Maximum number of calls:',data['Total night calls'].max())
print('Minimum number of calls:',data['Total night calls'].min())
print('Average number of calls:',data['Total night calls'].mean())
# Out:
# Maximum number of calls: 175
# Minimum number of calls: 33
# Average number of calls: 100.10771077107711

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total night calls',width=0.2, data = data)

# %% [markdown]
# Still Calls are made more by the churned customers!!¶

# %% [markdown]
# Checking Total night charges affecting churn rate.
#
# ---

# %%
print('Maximum number of charge:',data['Total night charge'].max())
print('Minimum number of charge:',data['Total night charge'].min())
print('Average number of charge:',data['Total night charge'].mean())
# Out:
# Maximum number of charge: 17.77
# Minimum number of charge: 1.04
# Average number of charge: 9.039324932493264

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total night charge',width=0.2, data = data)

# %% [markdown]
# Again Optimization of The Charges would lead to a loyal customer!!!¶

# %% [markdown]
# # 4.3.5  International Calls Affecting the Churn Rate.

# %% [markdown]
#  Checking Total international minutes affecting churn rate
#
# ---

# %%
print('Maximum number of minutes:',data['Total intl minutes'].max(),'i.e. Max number of Hours  spent:',round(data['Total intl minutes'].max()/60))
print('Minimum number of minutes:',data['Total intl minutes'].min())
print('Average number of minutes:',data['Total intl minutes'].mean())
# Out:
# Maximum number of minutes: 20.0 i.e. Max number of Hours  spent: 0
# Minimum number of minutes: 0.0
# Average number of minutes: 10.237293729372933

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total intl minutes',width=0.2, data = data)

# %% [markdown]
# Different Pricing Strategy and International Calling Rate Optimization would lead to lower churn rate

# %% [markdown]
#   Checking total international calls affecting churn rate`
#
# ---

# %%
print('Maximum number of calls:',data['Total intl calls'].max())
print('Minimum number of calls:',data['Total intl calls'].min())
print('Average number of calls:',data['Total intl calls'].mean())
# Out:
# Maximum number of calls: 20
# Minimum number of calls: 0
# Average number of calls: 4.4794479447944795

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total intl calls',width=0.2, data = data)

# %% [markdown]
#  Checking Total international charge affecting Churn rate.
#
# ---

# %%
print('Maximum number of charge:',data['Total intl charge'].max())
print('Minimum number of charge:',data['Total intl charge'].min())
print('Average number of charge:',data['Total intl charge'].mean())
# Out:
# Maximum number of charge: 5.4
# Minimum number of charge: 0.0
# Average number of charge: 2.764581458145804

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Churn', y ='Total intl charge',width=0.2, data = data)

# %%
#Calculate the International Plan vs Churn percentage 
International_plan_data = pd.crosstab(data["International plan"],data["Churn"])
International_plan_data['Percentage Churn'] = International_plan_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(International_plan_data)
# Out:
# Churn               False  True  Percentage Churn
# International plan
# 0                    2664   346         11.495017
# 1                     186   137         42.414861

# %% [markdown]
# Reasons for churns
#
# 1.Different Pricing Strategy and International Calling Rate Optimization would lead to lower churn rate.
#
#
# 2.Of those with an international system 42.4% of the population churned out.

# %% [markdown]
# #5. Churn According to States.

# %%
# By Age
fig, axz = plt.subplots(figsize=(20,15))

axz = sns.countplot(x='State', hue='Churn', data=data, palette='Blues')


axz.set_ylabel('COUNTS', rotation=0, labelpad=120,size=20)
axz.set_xlabel('State', size=20)
axz.yaxis.set_label_coords(0.05, 0.95)  # (x, y)
axz.legend(loc=0,fontsize=20);

axz.tick_params(labelsize=10)  # Changes size of the values on the label

# %%
plt.rcParams['figure.figsize'] = (12, 7)
color = plt.cm.copper(np.linspace(0, 0.5, 20))
((data.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = False).head(6).plot.bar(color = ['red','black','b','g','y','orange','r'])
plt.title(" State with most churn percentage", fontsize = 20)
plt.xlabel('State', fontsize = 15)
plt.ylabel('percentage', fontsize = 15)
plt.show()

# %% [markdown]
# Analysis:
#
# New Jersey, California, Texas, Maryland, South Carolina and Michigan have a higher Churn rate than usual.
#
# Network Development can be highly recommended in these areas.

# %% [markdown]
# # 8.Checking Churn for Customer service Calls.

# %%
# Customer Calls
fig, axz = plt.subplots(figsize=(20,15))

axz = sns.countplot(x='Customer service calls', hue='Churn', data=data, palette='Blues')


axz.set_ylabel('COUNTS', rotation=0, labelpad=100,size=20)
axz.set_xlabel('Customer Service Calls', size=20)
axz.yaxis.set_label_coords(-0.05, 0.95)  # (x, y)
axz.legend(loc=0,fontsize=20);

axz.tick_params(labelsize=15)  # Changes size of the values on the label

# %% [markdown]
# Although some customers are lazy so without problem solving they jump to another network operator, while customers call and they have a high level of access indicating that their problem was not resolved in the first attempt.
#
# Answer is needed in such cases. Assurance to the Customer should be given that there is a problem to be resolved in the first attempt
#
# It is noteworthy in the analysis above that, mainly due to poor customer service, people often leave the operator.
#
# The above data shows that those customers have called the service center 5 times or more of those customer transactions of more than 60%,
#
# And the customers who beat them also had a high entry level indicating that their problem was not resolved in the first attempt.
#
# So the user has to work to improve the service call.

# %% [markdown]
# new

# %% [markdown]
# # 9.multi varaite analysis

# %%
#Finding  the relationship between total phone bills and total phone minutes

day_charge_m = data['Total day charge'].mean()/data['Total day minutes'].mean()
eve_charge_m = data['Total eve charge'].mean()/data['Total eve minutes'].mean()
night_charge_m = data['Total night charge'].mean()/data['Total night minutes'].mean()
int_charge_m= data['Total intl charge'].mean()/data['Total intl minutes'].mean()

# %%
sns.barplot(x=['Day','Evening','Night','International'],y=[day_charge_m,eve_charge_m,night_charge_m,int_charge_m])

# %% [markdown]
# After analyzing the above data we have observed that the full minute day / night / night / evening / call / cost is not set for any type of churn rate. But the cost of international calls is high compared to others it is obvious but that may be the reason why international system customers are out.

# %% [markdown]
# #  Conclusion

# %% [markdown]
# 1.Upgrading their services while on the Emergency only during the evening as low network traffic.
# .
#
# 2.Install better network infrastructure in New Jersey, California, Texas, Maryland, South Carolina and Michigan Areas where there is an additional Churn Rate.
#
# 3.Upgrading the network to improve services for long-term users.
# Updating Price Strategies.
#
#
# 4.
# Updating and Improving International Telephone Rates.
